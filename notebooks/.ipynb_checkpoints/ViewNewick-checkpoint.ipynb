# %% [markdown]
# **This notebook formats long names in newick files, to make them more Human readable.**

# %% [markdown]
# # Imports

# %%
import os
import ete3
from ete3 import Tree, TreeStyle, NodeStyle, AttrFace

# %% [markdown]
# # Declares

# %%
NEWICK_FILE = os.path.join("..", 
                           "results", 
                           "mammalian_REM2", 
                           "mammalian_REM2_codons.SA.FilterOutliers.fasta.treefile")

# %%
from ete3 import Tree

# Function to trim or modify the name
def trim_name(name):
    # Example: Trim the name to the first 10 characters
    edit = name.split("_")
    trimed_name = ""
    try:
        index = edit.index("RRAD")
    except:
        try:
            index = edit.index("RAS")
        except:
            try:
                index = edit.index("rad")
            except:
                try:
                    index = edit.index("GTP")
                except:
                    index = 10
            # end try
        # end try
    # end try
    
    if "PREDICTED" in edit:
        trimed_name = " ".join(edit[4:index])
    else:
        trimed_name = " ".join(edit[3:index])
    #end if
    return trimed_name

# Load the tree from a file
tree = Tree(NEWICK_FILE, format=1)  # Make sure the format matches your tree file

# Iterate through all tree nodes and modify their names
for node in tree.traverse():
    if node.is_leaf():  # Check if the node is a leaf
        node.name = trim_name(node.name)

# Save the modified tree to a new file
tree.write(outfile="modified_tree.nwk", format=1)  # format=1 to preserve branch lengths and bootstrap values

# %%
t = Tree(NEWICK_FILE, format=1 )

for node in t.traverse("postorder"):
    edit = node.name.split("_")
    print(edit)
    try:
        index = edit.index("RRAD")
    except:
        index = 5
    # end try
    
    if "PREDICTED" in edit:
        node.name = "_".join(edit[4:index])
    else:
        node.name = "_".join(edit[3:index])
    #end if
#end for
# Out:
# ['NM', '001192708', '1', 'Bos', 'taurus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '2']
# ['NM', '022685', '2', 'Rattus', 'norvegicus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '032918139', '1', 'PREDICTED', 'Rattus', 'rattus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['XM', '028788542', '1', 'PREDICTED', 'Grammomys', 'surdaster', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '034498612', '1', 'PREDICTED', 'Arvicanthis', 'niloticus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['43']
# ['NM', '080726', '3', 'Mus', 'musculus', 'rad', 'and', 'gem', 'related', 'GTP', 'binding', 'protein', '2', 'Rem2', 'mRNA', '1']
# ['XM', '021182512', '1', 'PREDICTED', 'Mus', 'caroli', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['XM', '021203619', '1', 'PREDICTED', 'Mus', 'pahari', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['98']
# ['XM', '031361298', '1', 'PREDICTED', 'Mastomys', 'coucha', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['43']
# ['XM', '052190525', '1', 'PREDICTED', 'Apodemus', 'sylvaticus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC127690950', 'mRNA', '1']
# ['32']
# ['100']
# ['XM', '021639619', '1', 'PREDICTED', 'Meriones', 'unguiculatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '051143407', '1', 'PREDICTED', 'Acomys', 'russatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC127187235', 'mRNA', '1']
# ['81']
# ['76']
# ['XM', '005085570', '4', 'PREDICTED', 'Mesocricetus', 'auratus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '051195738', '1', 'PREDICTED', 'Phodopus', 'roborovskii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC127230422', 'mRNA', '1']
# ['62']
# ['XM', '027390645', '2', 'PREDICTED', 'Cricetulus', 'griseus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'transcript', 'variant', 'X2', 'mRNA', '1']
# ['86']
# ['XM', '026777673', '1', 'PREDICTED', 'Microtus', 'ochrogaster', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '041634112', '1', 'PREDICTED', 'Microtus', 'oregoni', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['74']
# ['XM', '050126229', '1', 'PREDICTED', 'Microtus', 'fortis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC126490927', 'mRNA', '1']
# ['100']
# ['XM', '048444987', '1', 'PREDICTED', 'Myodes', 'glareolus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['94']
# ['XM', '038310306', '1', 'PREDICTED', 'Arvicola', 'amphibius', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['65']
# ['XM', '006988484', '2', 'PREDICTED', 'Peromyscus', 'maniculatus', 'bairdii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '028892240', '2', 'PREDICTED', 'Peromyscus', 'leucopus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['XM', '036199393', '1', 'PREDICTED', 'Onychomys', 'torridus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['97']
# ['100']
# ['XM', '008839903', '2', 'PREDICTED', 'Nannospalax', 'galili', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['87']
# ['XM', '045154677', '1', 'PREDICTED', 'Jaculus', 'jaculus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['98']
# ['XM', '004646648', '2', 'PREDICTED', 'Octodon', 'degus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '005377113', '2', 'PREDICTED', 'Chinchilla', 'lanigera', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'Rem2', 'mRNA', '1']
# ['69']
# ['XM', '023567007', '1', 'PREDICTED', 'Cavia', 'porcellus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'transcript', 'variant', 'X2', 'mRNA', '1']
# ['96']
# ['XM', '004864195', '2', 'PREDICTED', 'Heterocephalus', 'glaber', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '033765070', '1', 'PREDICTED', 'Fukomys', 'damarensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['93']
# ['100']
# ['XM', '005338787', '4', 'PREDICTED', 'Ictidomys', 'tridecemlineatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '026406123', '1', 'PREDICTED', 'Urocitellus', 'parryii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['90']
# ['XM', '015492848', '2', 'PREDICTED', 'Marmota', 'marmota', 'marmota', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['XM', '027920156', '1', 'PREDICTED', 'Marmota', 'flaviventris', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '046465107', '1', 'PREDICTED', 'Marmota', 'monax', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['56']
# ['77']
# ['100']
# ['XM', '020162859', '1', 'PREDICTED', 'Castor', 'canadensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['35']
# ['XM', '013025368', '1', 'PREDICTED', 'Dipodomys', 'ordii', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'Rem2', 'mRNA', '1']
# ['XM', '042686425', '1', 'PREDICTED', 'Dipodomys', 'spectabilis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['XM', '048362803', '1', 'PREDICTED', 'Perognathus', 'longimembris', 'pacificus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'Rem2', 'mRNA', '1']
# ['100']
# ['38']
# ['31']
# ['85']
# ['XM', '004584677', '1', 'PREDICTED', 'Ochotona', 'princeps', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '040969296', '1', 'PREDICTED', 'Ochotona', 'curzoniae', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['XM', '051822640', '1', 'PREDICTED', 'Oryctolagus', 'cuniculus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC100344089', 'mRNA', '1']
# ['96']
# ['XM', '007536758', '2', 'PREDICTED', 'Erinaceus', 'europaeus', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['10']
# ['XM', '004609481', '1', 'PREDICTED', 'Sorex', 'araneus', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '049768637', '1', 'PREDICTED', 'Suncus', 'etruscus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC126001377', 'mRNA', '1']
# ['100']
# ['XM', '007479801', '2', 'PREDICTED', 'Monodelphis', 'domestica', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '044662280', '1', 'PREDICTED', 'Gracilinanus', 'agilis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '021008842', '1', 'PREDICTED', 'Phascolarctos', 'cinereus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '027843188', '1', 'PREDICTED', 'Vombatus', 'ursinus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X2', 'mRNA', '1']
# ['97']
# ['XM', '036737107', '1', 'PREDICTED', 'Trichosurus', 'vulpecula', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['43']
# ['XM', '031955028', '1', 'PREDICTED', 'Sarcophilus', 'harrisii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '051980438', '1', 'PREDICTED', 'Antechinus', 'flavipes', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC127551038', 'mRNA', '1']
# ['100']
# ['22']
# ['28']
# ['XM', '043980377', '1', 'PREDICTED', 'Dromiciops', 'gliroides', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '029077766', '2', 'PREDICTED', 'Ornithorhynchus', 'anatinus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '038741379', '1', 'PREDICTED', 'Tachyglossus', 'aculeatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['100']
# ['64']
# ['39']
# ['29']
# ['NM', '173527', '3', 'Homo', 'sapiens', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '008960213', '2', 'PREDICTED', 'Pan', 'paniscus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '009427474', '3', 'PREDICTED', 'Pan', 'troglodytes', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['63']
# ['XM', '019009447', '1', 'PREDICTED', 'Gorilla', 'gorilla', 'gorilla', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['99']
# ['XM', '002824566', '3', 'PREDICTED', 'Pongo', 'abelii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['89']
# ['XM', '003260595', '2', 'PREDICTED', 'Nomascus', 'leucogenys', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '032179928', '1', 'PREDICTED', 'Hylobates', 'moloch', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['98']
# ['XM', '001100692', '4', 'PREDICTED', 'Macaca', 'mulatta', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '005560816', '3', 'PREDICTED', 'Macaca', 'fascicularis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['45']
# ['XM', '011772352', '2', 'PREDICTED', 'Macaca', 'nemestrina', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['5']
# ['XM', '012088533', '1', 'PREDICTED', 'Cercocebus', 'atys', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['2']
# ['XM', '011990630', '1', 'PREDICTED', 'Mandrillus', 'leucophaeus', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '050796554', '1', 'PREDICTED', 'Macaca', 'thibetana', 'thibetana', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC126958288', 'mRNA', '1']
# ['13']
# ['4']
# ['XM', '003901565', '5', 'PREDICTED', 'Papio', 'anubis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '025392475', '1', 'PREDICTED', 'Theropithecus', 'gelada', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['59']
# ['59']
# ['XM', '037987559', '1', 'PREDICTED', 'Chlorocebus', 'sabaeus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['77']
# ['XM', '010378358', '2', 'PREDICTED', 'Rhinopithecus', 'roxellana', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '017864286', '1', 'PREDICTED', 'Rhinopithecus', 'bieti', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['72']
# ['XM', '033188604', '1', 'PREDICTED', 'Trachypithecus', 'francoisi', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['71']
# ['XM', '023230440', '1', 'PREDICTED', 'Piliocolobus', 'tephrosceles', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['80']
# ['XM', '011930962', '1', 'PREDICTED', 'Colobus', 'angolensis', 'palliatus', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['51']
# ['100']
# ['98']
# ['XM', '003924335', '3', 'PREDICTED', 'Saimiri', 'boliviensis', 'boliviensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '012466673', '1', 'PREDICTED', 'Aotus', 'nancymaae', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '017544499', '2', 'PREDICTED', 'Cebus', 'imitator', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '032265550', '1', 'PREDICTED', 'Sapajus', 'apella', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['95']
# ['97']
# ['81']
# ['XM', '035260095', '1', 'PREDICTED', 'Callithrix', 'jacchus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['100']
# ['XM', '008065271', '2', 'PREDICTED', 'Carlito', 'syrichta', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['47']
# ['XM', '003801909', '3', 'PREDICTED', 'Otolemur', 'garnettii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '012649447', '1', 'PREDICTED', 'Propithecus', 'coquereli', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '012752689', '1', 'PREDICTED', 'Microcebus', 'murinus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '045525960', '1', 'PREDICTED', 'Lemur', 'catta', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['37']
# ['66']
# ['100']
# ['65']
# ['XM', '008566551', '1', 'PREDICTED', 'Galeopterus', 'variegatus', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['19']
# ['XM', '006144596', '3', 'PREDICTED', 'Tupaia', 'chinensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['13']
# ['18']
# ['XM', '003420937', '2', 'PREDICTED', 'Loxodonta', 'africana', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '049899603', '1', 'PREDICTED', 'Elephas', 'maximus', 'indicus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC126084786', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '023724898', '1', 'PREDICTED', 'Trichechus', 'manatus', 'latirostris', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC101345257', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['46']
# ['XM', '006883133', '1', 'PREDICTED', 'Elephantulus', 'edwardii', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['38']
# ['XM', '006835452', '1', 'PREDICTED', 'Chrysochloris', 'asiatica', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '045287665', '1', 'PREDICTED', 'Echinops', 'telfairi', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['69']
# ['XM', '007951171', '2', 'PREDICTED', 'Orycteropus', 'afer', 'afer', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['57']
# ['100']
# ['XM', '004474567', '2', 'PREDICTED', 'Dasypus', 'novemcinctus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '037835533', '1', 'PREDICTED', 'Choloepus', 'didactylus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['95']
# ['78']
# ['40']
# ['XM', '004694658', '2', 'PREDICTED', 'Condylura', 'cristata', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '037503036', '1', 'PREDICTED', 'Talpa', 'occidentalis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['XM', '006913609', '2', 'PREDICTED', 'Pteropus', 'alecto', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '011372778', '2', 'PREDICTED', 'Pteropus', 'vampyrus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '039851849', '1', 'PREDICTED', 'Pteropus', 'giganteus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['96']
# ['99']
# ['XM', '016120537', '2', 'PREDICTED', 'Rousettus', 'aegyptiacus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['XM', '019663177', '1', 'PREDICTED', 'Hipposideros', 'armiger', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '033107547', '1', 'PREDICTED', 'Rhinolophus', 'ferrumequinum', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC117023075', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['67']
# ['XM', '016205757', '1', 'PREDICTED', 'Miniopterus', 'natalensis', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '036355955', '1', 'PREDICTED', 'Myotis', 'myotis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '028507134', '2', 'PREDICTED', 'Phyllostomus', 'discolor', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '045841219', '1', 'PREDICTED', 'Phyllostomus', 'hastatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['XM', '037037712', '1', 'PREDICTED', 'Sturnira', 'hondurensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '037129407', '1', 'PREDICTED', 'Artibeus', 'jamaicensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['97']
# ['100']
# ['98']
# ['57']
# ['29']
# ['45']
# ['XM', '004421250', '2', 'PREDICTED', 'Ceratotherium', 'simum', 'simum', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'LOC101388298', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '008528968', '1', 'PREDICTED', 'Equus', 'przewalskii', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '023622024', '1', 'PREDICTED', 'Equus', 'caballus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['80']
# ['XM', '014856335', '2', 'PREDICTED', 'Equus', 'asinus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['67']
# ['XM', '046653592', '1', 'PREDICTED', 'Equus', 'quagga', 'GTP', 'binding', 'protein', 'REM', '2', 'LOC124235489', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['56']
# ['45']
# ['XM', '003987456', '6', 'PREDICTED', 'Felis', 'catus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '030318679', '1', 'PREDICTED', 'Lynx', 'canadensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '043555763', '1', 'PREDICTED', 'Prionailurus', 'bengalensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['71']
# ['58']
# ['XM', '045450372', '1', 'PREDICTED', 'Leopardus', 'geoffroyi', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['30']
# ['XM', '015086639', '2', 'PREDICTED', 'Acinonyx', 'jubatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '025919283', '1', 'PREDICTED', 'Puma', 'concolor', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['59']
# ['77']
# ['XM', '019429463', '1', 'PREDICTED', 'Panthera', 'pardus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['23']
# ['XM', '007098093', '3', 'PREDICTED', 'Panthera', 'tigris', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X3', 'mRNA', '1']
# ['47']
# ['XM', '049613126', '1', 'PREDICTED', 'Panthera', 'uncia', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['58']
# ['XM', '042942694', '1', 'PREDICTED', 'Panthera', 'leo', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '029952605', '1', 'PREDICTED', 'Suricata', 'suricatta', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '039245203', '1', 'PREDICTED', 'Hyaena', 'hyaena', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['97']
# ['100']
# ['XM', '004402108', '1', 'PREDICTED', 'Odobenus', 'rosmarus', 'divergens', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '025870359', '1', 'PREDICTED', 'Callorhinus', 'ursinus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '027571459', '2', 'PREDICTED', 'Zalophus', 'californianus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '2']
# ['100']
# ['90']
# ['XM', '021695575', '1', 'PREDICTED', 'Neomonachus', 'schauinslandi', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '031036681', '1', 'PREDICTED', 'Leptonychotes', 'weddellii', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '034994691', '1', 'PREDICTED', 'Mirounga', 'leonina', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '045900528', '1', 'PREDICTED', 'Mirounga', 'angustirostris', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['75']
# ['100']
# ['63']
# ['XM', '032404536', '1', 'PREDICTED', 'Phoca', 'vitulina', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '036114829', '1', 'PREDICTED', 'Halichoerus', 'grypus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['72']
# ['100']
# ['95']
# ['XM', '004755362', '3', 'PREDICTED', 'Mustela', 'putorius', 'furo', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '032343807', '1', 'PREDICTED', 'Mustela', 'erminea', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '022520471', '1', 'PREDICTED', 'Enhydra', 'lutris', 'kenyoni', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC111158448', 'mRNA', '1']
# ['XM', '032856406', '1', 'PREDICTED', 'Lontra', 'canadensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['98']
# ['94']
# ['XM', '046008309', '1', 'PREDICTED', 'Meles', 'meles', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '040620901', '1', 'PREDICTED', 'Ursus', 'maritimus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '3']
# ['38']
# ['38']
# ['XM', '005623217', '4', 'PREDICTED', 'Canis', 'lupus', 'familiaris', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '025442827', '3', 'PREDICTED', 'Canis', 'lupus', 'dingo', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['XM', '026007504', '1', 'PREDICTED', 'Vulpes', 'vulpes', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '041758862', '1', 'PREDICTED', 'Vulpes', 'lagopus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['98']
# ['100']
# ['99']
# ['98']
# ['26']
# ['XM', '017665172', '2', 'PREDICTED', 'Manis', 'javanica', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '036884595', '1', 'PREDICTED', 'Manis', 'pentadactyla', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['100']
# ['98']
# ['XM', '004283191', '4', 'PREDICTED', 'Orcinus', 'orca', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'LOC101284288', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '027110778', '1', 'PREDICTED', 'Lagenorhynchus', 'obliquidens', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '030854517', '1', 'PREDICTED', 'Globicephala', 'melas', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['21']
# ['22']
# ['XM', '033851357', '1', 'PREDICTED', 'Tursiops', 'truncatus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['51']
# ['XM', '022553601', '2', 'PREDICTED', 'Delphinapterus', 'leucas', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '029237411', '1', 'PREDICTED', 'Monodon', 'monoceros', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['89']
# ['XM', '024741692', '1', 'PREDICTED', 'Neophocaena', 'asiaeorientalis', 'asiaeorientalis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '032622712', '1', 'PREDICTED', 'Phocoena', 'sinus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['93']
# ['71']
# ['95']
# ['XM', '007449526', '1', 'PREDICTED', 'Lipotes', 'vexillifer', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['95']
# ['XM', '007100477', '2', 'PREDICTED', 'Physeter', 'catodon', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '007180539', '1', 'PREDICTED', 'Balaenoptera', 'acutorostrata', 'scammoni', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '036842027', '1', 'PREDICTED', 'Balaenoptera', 'musculus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['97']
# ['49']
# ['100']
# ['XM', '021099265', '1', 'PREDICTED', 'Sus', 'scrofa', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['51']
# ['XM', '031452725', '1', 'PREDICTED', 'Camelus', 'dromedarius', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '032481695', '1', 'PREDICTED', 'Camelus', 'ferus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['98']
# ['XM', '031678770', '1', 'PREDICTED', 'Vicugna', 'pacos', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['100']
# ['44']
# ['100']
# ['XM', '018054571', '1', 'PREDICTED', 'Capra', 'hircus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '027971647', '2', 'PREDICTED', 'Ovis', 'aries', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['98']
# ['XM', '040227220', '1', 'PREDICTED', 'Oryx', 'dammah', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['53']
# ['43']
# ['XM', '020909415', '1', 'PREDICTED', 'Odocoileus', 'virginianus', 'texanus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '043471209', '1', 'PREDICTED', 'Cervus', 'canadensis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['XM', '043919551', '1', 'PREDICTED', 'Cervus', 'elaphus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X1', 'mRNA', '1']
# ['95']
# ['100']
# ['96']
# ['XM', '025296072', '3', 'PREDICTED', 'Bubalus', 'bubalis', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'transcript', 'variant', 'X4', 'mRNA', '1']
# ['83']
# ['XM', '010831252', '1', 'PREDICTED', 'Bison', 'bison', 'bison', 'RAS', 'RAD', 'and', 'GEM', 'like', 'GTP', 'binding', '2', 'REM2', 'mRNA', '1']
# ['XM', '019968374', '1', 'PREDICTED', 'Bos', 'indicus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['XM', '027553330', '1', 'PREDICTED', 'Bos', 'indicus', 'x', 'Bos', 'taurus', 'RRAD', 'and', 'GEM', 'like', 'GTPase', '2', 'REM2', 'mRNA', '1']
# ['64']
# ['24']
# ['']

# %%
# Save the tree to a file in Newick format
t.write(outfile="my_tree.nwk")

# %%
t = Tree(NEWICK_FILE, format=1 )
newick_dict = {}

for node in t.traverse("postorder"):
    #print(node.name.split("_"))
    original_name = node.name
    edit = node.name.split("_")
    #print(edit)
    # get location of RRAD
    if "RRAD" in edit:
        location = edit.index("RRAD") - 1
    elif "rad" in edit:
        location = edit.index("rad") - 1
    else:
        location = 5
    #end if
    
    if "PREDICTED" in edit:
        node.name = "_".join(edit[4: location + 1])
        newick_dict[original_name] = node.name 
    else:
        node.name = "_".join(edit[3: location + 1])
        newick_dict[original_name] = node.name 
    #end if
#end for

# init tree style
ts = TreeStyle()
# remove default labels
ts.show_leaf_name = False

widthscale= 2400

heightscale=5

height = t.get_farthest_node()[1]

ts.scale = widthscale / height

ts.branch_vertical_margin = heightscale

for n in t.traverse():
    nstyle = ete3.NodeStyle()
    nstyle['hz_line_width'] = 2
    nstyle['vt_line_width'] = 2
    nstyle['hz_line_color'] = 'black'
    nstyle['vt_line_color'] = 'black'
    nstyle['size'] = 8
    nstyle['shape'] = 'square'
    
    n.add_face(ete3.TextFace(f" {n.name}",
                                     ftype='Dejavu Sans',
                                     tight_text=True,
                                     fsize=14,
                                     fgcolor='black',
                                     ),
                                     column=0, 
                                     position='branch-right')
    
    
    
    n.set_style(nstyle)
#end for 
    
# render image on notebook
t.render("%%inline", tree_style=ts)
# Out:
# qt.qpa.fonts: Populating font family aliases took 52 ms. Replace uses of missing font family "Dejavu Sans" with one that exists to avoid this cost.

# %%
print("Number of nodes:", len(newick_dict.keys()))
# Out:
# Number of nodes: 240

# %%
# mammalian_REM2_codons.SA.FilterOutliers.fasta.treefile
NEWICK_FILE_LABELLED = os.path.join("..", "results", "mammalian_REM2", "mammalian_REM2_codons.SA.FilterOutliers.fasta.treefile")

with open(NEWICK_FILE_LABELLED, "r") as fh:
    newick_data = fh.readline()
    fh.close()
#end with

for item in newick_dict.keys():
    if item in newick_data:
        #print(newick_dict[item])
        newick_data = newick_data.replace(item, newick_dict[item])
    #end if
#end for

newick_data
# Out:
# '(Bos_taurus:0.00000116,(((((((((((((((((((Rattus_norvegicus:0.000009,Rattus_rattus:0.0061):0.0916,(Grammomys_surdaster:0.0733,Arvicanthis_niloticus:0.003):0.060009):0.0010,((((Mus_musculus:0.0087,Mus_caroli:0.007):0.0600,Mus_pahari:0.01):0.00790,XM_0361_1_PREDICTED_Mastomys_coucha_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.01108):0.0006,Apodemus_sylvaticus:0.0):0.003):0.01,(Meriones_unguiculatus:0.017,XM_01107_1_PREDICTED_Acomys_russatus_RRAD_and_GEM_like_GTPase__LOC1_mRNA_1:0.0):0.001):0.001,((((Mesocricetus_auratus:0.07,Phodopus_roborovskii:0.08):0.006,Cricetulus_griseus:0.01708):0.007,((((XM_03_1_PREDICTED_Microtus_ochrogaster_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.0010,Microtus_oregoni:0.00):0.000709,XM_00_1_PREDICTED_Microtus_fortis_RRAD_and_GEM_like_GTPase__LOC17_mRNA_1:0.00000):0.0003,XM_087_1_PREDICTED_Myodes_glareolus_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.01116):0.00,Arvicola_amphibius:0.00):0.08):0.00,((XM_00688__PREDICTED_Peromyscus_maniculatus_bairdii_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.0,Peromyscus_leucopus:0.00011):0.011,Onychomys_torridus:0.00801):0.008):0.011033607):0.086,Nannospalax_galili:0.03):0.011706,Jaculus_jaculus:0.079):0.0,((((Octodon_degus:0.00,Chinchilla_lanigera:0.017):0.0060,Cavia_porcellus:0.008):0.0097,(XM_00__PREDICTED_Heterocephalus_glaber_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.0,XM_070_1_PREDICTED_Fukomys_damarensis_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.08):0.00):0.0,((((XM_0033__PREDICTED_Ictidomys_tridecemlineatus_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.006111,Urocitellus_parryii:0.0017):0.003,(Marmota_marmota_marmota:0.000968,(Marmota_flaviventris:0.001,XM_07_1_PREDICTED_Marmota_monax_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.0017):0.00000):0.007):0.0,XM_00_1_PREDICTED_Castor_canadensis_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.03):0.00791,((Dipodomys_ordii:0.0070,XM_0_1_PREDICTED_Dipodomys_spectabilis_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.00388):0.00,XM_03_1_PREDICTED_Perognathus_longimembris_pacificus_RRAD_and_GEM_like_GTPase__Rem_mRNA_1:0.007):0.003):0.00160):0.0017):0.01,((((XM_0086_1_PREDICTED_Ochotona_princeps_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.0170,XM_009_1_PREDICTED_Ochotona_curzoniae_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.0116):0.01,XM_01_1_PREDICTED_Oryctolagus_cuniculus_RRAD_and_GEM_like_GTPase__LOC_mRNA_1:0.06):0.09700,Erinaceus_europaeus:0.10):0.00331,((XM_0060_1_PREDICTED_Sorex_araneus_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1:0.060,XM_07_1_PREDICTED_Suncus_etruscus_RRAD_and_GEM_like_GTPase__LOC1600_mRNA_1:0.0):0.079,((((XM_00701__PREDICTED_Monodelphis_domestica_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1:0.0001,XM_060_1_PREDICTED_Gracilinanus_agilis_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1:0.036):0.0888,(((XM_08_1_PREDICTED_Phascolarctos_cinereus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1:0.0061,XM_08_1_PREDICTED_Vombatus_ursinus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X_mRNA_1:0.0079117):0.01,XM_037_1_PREDICTED_Trichosurus_vulpecula_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.0388):0.00608,(XM_090_1_PREDICTED_Sarcophilus_harrisii_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.017,XM_08_1_PREDICTED_Antechinus_flavipes_RRAD_and_GEM_like_GTPase__LOC17_mRNA_1:0.011):0.0):0.00):0.000,XM_003_1_PREDICTED_Dromiciops_gliroides_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1:0.0):0.16173,(XM_06__PREDICTED_Ornithorhynchus_anatinus_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.00,XM_079_1_PREDICTED_Tachyglossus_aculeatus_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.00):0.11):0.00):0.0):0.00):0.0079,((((((((((NM_177_3_Homo_sapiens_RRAD_and_GEM_like_GTPase__REM_mRNA_1:0.00000,(XM_00__PREDICTED_Pan_paniscus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1:0.0011703,XM_00_3_PREDICTED_Pan_troglodytes_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1:0.00000116):0.0006):0.00607,XM_07_1_PREDICTED_Gorilla_gorilla_gorilla_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1:0.006):0.009,XM_006_3_PREDICTED_Pongo_abelii_RRAD_and_GEM_like_GTP ...

# %% [markdown]
# # Labelled Tree

# %%
# mammalian_REM2_codons.SA.FilterOutliers.fasta.treefile
NEWICK_FILE_LABELLED = os.path.join("..", "results", "mammalian_REM2", "mammalian_REM2_codons.SA.FilterOutliers.fasta.treefile.labelled")

with open(NEWICK_FILE_LABELLED, "r") as fh:
    newick_data = fh.readline()
    fh.close()
#end with

for item in newick_dict.keys():
    if item in newick_data:
        #print(newick_dict[item])
        newick_data = newick_data.replace(item, newick_dict[item])
    #end if
#end for

newick_data
# Out:
# '(Mus_musculus{Glires}:0.0079,((((((((((((((((((((((XM_00_3_PREDICTED_Pan_troglodytes_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:1.017e-06,XM_00__PREDICTED_Pan_paniscus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.0011707)Node3{Primates}:0.007,NM_177_3_Homo_sapiens_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:.01e-06)Node{Primates}:0.0033,XM_07_1_PREDICTED_Gorilla_gorilla_gorilla_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.0063)Node1{Primates}:0.00,XM_006_3_PREDICTED_Pongo_abelii_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.0080000001)Node0{Primates}:0.009,(XM_00609__PREDICTED_Nomascus_leucogenys_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.003,XM_017_1_PREDICTED_Hylobates_moloch_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.0009)Node{Primates}:0.0077)Node{Primates}:0.0086,((((XM_001__PREDICTED_Macaca_mulatta_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.00,XM_0006_3_PREDICTED_Macaca_fascicularis_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:.9e-06)Node{Primates}:0.006,(((XM_00__PREDICTED_Papio_anubis_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.00703,XM_07_1_PREDICTED_Theropithecus_gelada_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:.07e-06)Node0{Primates}:0.0077,XM_0079_1_PREDICTED_Macaca_thibetana_thibetana_RRAD_and_GEM_like_GTPase__LOC8_mRNA_1{Primates}:0.006)Node{Primates}:.0e-06,((XM_011__PREDICTED_Macaca_nemestrina_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.00,XM_010_1_PREDICTED_Mandrillus_leucophaeus_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1{Primates}:0.007)Node{Primates}:.8e-06,XM_0103_1_PREDICTED_Cercocebus_atys_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1{Primates}:0.000)Node{Primates}:.e-06)Node{Primates}:.e-06)Node3{Primates}:0.008,XM_09_1_PREDICTED_Chlorocebus_sabaeus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.00)Node33{Primates}:0.007,((XM_008_1_PREDICTED_Equus_przewalskii_RAS_RAD_and_GEM_like_GTP_binding__REM_transcript_variant_X1_mRNA_1{Perissodactyla}:0.11,XM_0_1_PREDICTED_Colobus_angolensis_palliatus_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1{Primates}:0.0708)Node1:0.0,(((XM_088__PREDICTED_Rhinopithecus_roxellana_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.00,XM_01_1_PREDICTED_Rhinopithecus_bieti_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:1.017e-06)Node{Primates}:0.0076,XM_03_1_PREDICTED_Trachypithecus_francoisi_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.0073)Node{Primates}:0.00,XM_00_1_PREDICTED_Piliocolobus_tephrosceles_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.001)Node{Primates}:0.0061)Node0:.03e-06)Node:0.0)Node:0.0088,(XM_06009_1_PREDICTED_Callithrix_jacchus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.0161,(XM_00_3_PREDICTED_Saimiri_boliviensis_boliviensis_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.03,(XM_013_1_PREDICTED_Aotus_nancymaae_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.00,(XM_017__PREDICTED_Cebus_imitator_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.0011,XM_00_1_PREDICTED_Sapajus_apella_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.003691)Node{Primates}:0.00)Node{Primates}:0.007)Node{Primates}:0.0017)Node61{Primates}:0.01)Node17:0.0681,XM_00__PREDICTED_Carlito_syrichta_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.0761)Node16:0.009,(XM_000_3_PREDICTED_Otolemur_garnettii_RRAD_and_GEM_like_GTPase__REM_mRNA_1{Primates}:0.0373,(XM_017_1_PREDICTED_Propithecus_coquereli_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1{Primates}:0.061,(XM_0176_1_PREDICTED_Microcebus_murinus_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.013,XM_00_1_PREDICTED_Lemur_catta_RRAD_and_GEM_like_GTPase__REM_transcript_variant_X1_mRNA_1{Primates}:0.011)Node7{Primates}:0.00109)Node73{Primates}:0.0008)Node{Primates}:0.000)Node1:0.009,XM_001_1_PREDICTED_Galeopterus_variegatus_RAS_RAD_and_GEM_like_GTP_binding__REM_mRNA_1:0.01179)Node1:0. ...

# %%
# Save to file

# %%
# Enter into phylotree
# https://phylotree.hyphy.org/
