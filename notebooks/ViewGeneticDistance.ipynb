# %%
import os
import pandas as pd



TN93_FILE = os.path.join("H:\\", "AOC-REM2", "results", "mammalian_REM2", "mammalian_REM2_codons.SA.fasta.dst")

# %%
df = pd.read_csv(TN93_FILE)

# %%
df.T
# Out:
#                                                       0      \
# ID1       NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_lik...
# ID2       NM_080726_3_Mus_musculus_rad_and_gem_related_G...
# Distance                                           0.057631
#
#                                                       1      \
# ID1       NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_lik...
# ID2       NM_173527_3_Homo_sapiens_RRAD_and_GEM_like_GTP...
# Distance                                           0.143112
#
#                                                       2      \
# ID1       NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_lik...
# ID2       XM_009427474_3_PREDICTED_Pan_troglodytes_RRAD_...
# Distance                                            0.14584
#
#                                                       3      \
# ID1       NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_lik...
# ID2       XM_005623217_4_PREDICTED_Canis_lupus_familiari...
# ...

# %%
import altair as alt
from vega_datasets import data

# Since the data is more than 5,000 rows we'll import it from a URL
source = data.seattle_temps.url

alt.Chart(
    df,
    title="2010 Daily High Temperature (F) in Seattle, WA"
).mark_rect().encode(
    x='date(date):O',
    y='month(date):O',
    color=alt.Color('max(temp):Q', scale=alt.Scale(scheme="inferno")),
    tooltip=[
        alt.Tooltip('monthdate(date):T', title='Date'),
        alt.Tooltip('max(temp):Q', title='Max Temp')
    ]
).properties(width=550)

# %%
import seaborn as sns

# %%
#iris = sns.load_dataset("iris")
#species = iris.pop("species")
sns.clustermap(df)
# Out:
# c:\python39\lib\site-packages\seaborn\matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-6aed2671913a> in <module>
#       1 #iris = sns.load_dataset("iris")
#       2 #species = iris.pop("species")
# ----> 3 sns.clustermap(df)
#
# c:\python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
import csv

results_dict = {}
with open(TN93_FILE, 'r') as data:
    for line in csv.DictReader(data):
        #print(line)
        
        
        # {'NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_like_GTPase_2_Rem2_mRNA_1': {'NM_080726_3_Mus_musculus_rad_and_gem_related_GTP_binding_protein_2_Rem2_mRNA_1': 0.02848115779748788,
        
        if line["ID1"] in results_dict.keys():
            results_dict[line["ID1"]].update({line["ID2"]: float(line["Distance"])})
        else:
            results_dict[line["ID1"]] = {line["ID2"]: float(line["Distance"])}
        #end if

# %%
results_dict
# Out:
# {'NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_like_GTPase_2_Rem2_mRNA_1': {'NM_080726_3_Mus_musculus_rad_and_gem_related_GTP_binding_protein_2_Rem2_mRNA_1': 0.0576314,
#   'NM_173527_3_Homo_sapiens_RRAD_and_GEM_like_GTPase_2_REM2_mRNA_1': 0.143112,
#   'XM_009427474_3_PREDICTED_Pan_troglodytes_RRAD_and_GEM_like_GTPase_2_REM2_transcript_variant_X1_mRNA_1': 0.14584,
#   'XM_005623217_4_PREDICTED_Canis_lupus_familiaris_RRAD_and_GEM_like_GTPase_2_REM2_transcript_variant_X1_mRNA_1': 0.149276,
#   'NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GTPase_2_REM2_mRNA_2': 0.139324,
#   'XM_001100692_4_PREDICTED_Macaca_mulatta_RRAD_and_GEM_like_GTPase_2_REM2_mRNA_1': 0.147285,
#   'XM_007479801_2_PREDICTED_Monodelphis_domestica_RAS_RAD_and_GEM_like_GTP_binding_2_REM2_mRNA_1': 0.27643,
#   'XM_023622024_1_PREDICTED_Equus_caballus_RRAD_and_GEM_like_GTPase_2_REM2_transcript_variant_X1_mRNA_1': 0.131085,
# ...

# %%
df = pd.DataFrame.from_dict(results_dict)
df
# Out:
#                                                     NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_like_GTPase_2_Rem2_mRNA_1  \
# NM_080726_3_Mus_musculus_rad_and_gem_related_GT...                                           0.057631
# NM_173527_3_Homo_sapiens_RRAD_and_GEM_like_GTPa...                                           0.143112
# XM_009427474_3_PREDICTED_Pan_troglodytes_RRAD_a...                                           0.145840
# XM_005623217_4_PREDICTED_Canis_lupus_familiaris...                                           0.149276
# NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GTP...                                           0.139324
# ...                                                                                               ...
# XM_050796554_1_PREDICTED_Macaca_thibetana_thibe...                                           0.143245
# XM_051143407_1_PREDICTED_Acomys_russatus_RRAD_a...                                           0.093765
# ...

# %%
from matplotlib import pyplot as plt
import itertools
import numpy as np
from matplotlib.pyplot import figure

fig, ax = plt.subplots(figsize=(10,10))             # Sample figsize in inches

sns.heatmap(df, annot=False, linewidths=0, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Default plot
df = df.dropna('any')

sns.clustermap(df, cmap = 'RdBu', row_cluster=True, col_cluster=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-4f87b3ab9364> in <module>
#       2 df = df.dropna()
#       3
# ----> 4 sns.clustermap(df, cmap = 'RdBu', row_cluster=True, col_cluster=True)
#       5 plt.show()
#
# c:\python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\python39\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1404                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1405
# ...

# %%
df
# Out:
#                                                     NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_like_GTPase_2_Rem2_mRNA_1  \
# XM_052190525_1_PREDICTED_Apodemus_sylvaticus_RR...                                           0.064055
#
#                                                     NM_080726_3_Mus_musculus_rad_and_gem_related_GTP_binding_protein_2_Rem2_mRNA_1  \
# XM_052190525_1_PREDICTED_Apodemus_sylvaticus_RR...                                           0.052561
#
#                                                     NM_173527_3_Homo_sapiens_RRAD_and_GEM_like_GTPase_2_REM2_mRNA_1  \
# XM_052190525_1_PREDICTED_Apodemus_sylvaticus_RR...                                           0.133202
#
#                                                     XM_009427474_3_PREDICTED_Pan_troglodytes_RRAD_and_GEM_like_GTPase_2_REM2_transcript_variant_X1_mRNA_1  \
# XM_052190525_1_PREDICTED_Apodemus_sylvaticus_RR...                                           0.133334
#
# ...
