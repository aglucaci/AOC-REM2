# %%
import scipy.stats as st
from matplotlib.pyplot import figure
import sys, os
import matplotlib.pyplot as plt
import pandas as pd

# %%
TN93_DST_FILE = os.path.join("..", 
                         "results", 
                         "mammalian_REM2", 
                         "mammalian_REM2_codons.SA.FilterOutliers.fasta.dst")

# %%
df = pd.read_csv(TN93_DST_FILE)
df
# Out:
#                                                      ID1  \
# 0      NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GT...
# 1      NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GT...
# 2      NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GT...
# 3      NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GT...
# 4      NM_001192708_1_Bos_taurus_RRAD_and_GEM_like_GT...
# ...                                                  ...
# 15220  XM_051195738_1_PREDICTED_Phodopus_roborovskii_...
# 15221  XM_051195738_1_PREDICTED_Phodopus_roborovskii_...
# 15222  XM_051822640_1_PREDICTED_Oryctolagus_cuniculus...
# 15223  XM_051822640_1_PREDICTED_Oryctolagus_cuniculus...
# 15224  XM_051980438_1_PREDICTED_Antechinus_flavipes_R...
#
#                                                      ID2  Distance
# 0      NM_022685_2_Rattus_norvegicus_RRAD_and_GEM_lik...  0.139182
# 1      NM_080726_3_Mus_musculus_rad_and_gem_related_G...  0.138741
# 2      NM_173527_3_Homo_sapiens_RRAD_and_GEM_like_GTP...  0.090213
# 3      XM_001100692_4_PREDICTED_Macaca_mulatta_RRAD_a...  0.101121
# 4      XM_002824566_3_PREDICTED_Pongo_abelii_RRAD_and...  0.099749
# ...                                                  ...       ...
# 15220  XM_051980438_1_PREDICTED_Antechinus_flavipes_R...  0.279504
# 15221  XM_052190525_1_PREDICTED_Apodemus_sylvaticus_R...  0.086849
# 15222  XM_051980438_1_PREDICTED_Antechinus_flavipes_R...  0.267439
# 15223  XM_052190525_1_PREDICTED_Apodemus_sylvaticus_R...  0.143822
# 15224  XM_052190525_1_PREDICTED_Apodemus_sylvaticus_R...  0.283757
#
# [15225 rows x 3 columns]

# %%
hist = df.hist(bins=100)

# %%
df["Distance"].describe()
# Out:
# count    15225.000000
# mean         0.123914
# std          0.055923
# min          0.000000
# 25%          0.090259
# 50%          0.117001
# 75%          0.145343
# max          0.367119
# Name: Distance, dtype: float64

# %%
def describe_helper(series):
    splits = str(series.describe()).split()
    keys, values = "", ""
    for i in range(0, len(splits), 2):
        keys += "{:8}\n".format(splits[i])
        values += "{:>8}\n".format(splits[i+1])
    return keys, values

# %%
plt.hist(df["Distance"], bins=100)
plt.figtext(0.92, 0.5, str(df["Distance"].describe()))
#plt.figtext(1.05, .49, describe_helper(df["Distance"])[1], {'multialignment':'right'})
plt.show()
